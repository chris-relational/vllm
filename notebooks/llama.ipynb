# %%
import os
import util

# %% [markdown]
# # `meta-llama/Llama-3.2-1B-Instruct`

# %% [markdown]
# ## Inference using vLLM on host

# %% [markdown]
# ### Batch inference with the `LLM` class

# %%
from huggingface_hub import login

from util import Settings

SETTINGS = Settings.make(env_path="../.env")
login(SETTINGS.hf_finegrained_token)

# %%
import logging
import os

from vllm import LLM, SamplingParams

logging.getLogger("vllm").setLevel(logging.WARN)
llm = LLM(model="meta-llama/Llama-3.2-1B-Instruct")

prompts = [
    "Hello, my name is",
    "The president of the United States is",
    "The capital of France is",
    "The future of AI is",
]
# Create a sampling params object.
sampling_params = SamplingParams(temperature=0.8, top_p=0.95)
outputs = llm.generate(prompts, sampling_params)
# Out:
# WARNING 06-30 09:33:14 [config.py:3225] Your device 'cpu' doesn't support torch.bfloat16. Falling back to torch.float16 for compatibility.
# WARNING 06-30 09:33:14 [config.py:3276] Casting torch.bfloat16 to torch.float16.
# WARNING 06-30 09:33:14 [arg_utils.py:1498] The model has a long context length (131072). This may causeOOM during the initial memory profiling phase, or result in low performance due to small KV cache size. Consider setting --max-model-len to a smaller value.
# WARNING 06-30 09:33:14 [cpu.py:131] Environment variable VLLM_CPU_KVCACHE_SPACE (GiB) for CPU backend is not set, using 4 by default.
# WARNING 06-30 09:33:15 [cpu_worker.py:445] Auto thread-binding is not supported due to the lack of package numa and psutil,fallback to no thread-binding. To get better performance,please try to manually bind threads.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Adding requests:   0%|          | 0/4 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/4 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]

# %%
inout = zip((out.prompt for out in outputs), (out.outputs[0].text for out in outputs))
print(*(item for item in inout), sep=os.linesep)
# Out:
# ('Hello, my name is', " Vivian, and I'm excited to be the guest on today's show!")
# ('The president of the United States is', ' elected through a complex system that involves the Electoral College, which is a group of')
# ('The capital of France is', ' not Paris, but instead Rennes.\nRennes is the capital of the region')
# ('The future of AI is', " bright, and it's not just about the tech itself, but the societal implications")

# %% [markdown]
# ## Inference using `transformers`

# %%
llm = util.ModelConfig.from_pretrained("meta-llama/Llama-3.2-1B-Instruct")

# %%
# Call generate using a plain and an annotated prompt
plain_prompt = "Write 5 sentences of at least 5 words each, so that each sentence contains at least 1 word more than its orevious sentence."

messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": plain_prompt}
]

# tokenize=False will make the tokenizer return a string, otherwise a list with the token_ids is returned
annotated_prompt = llm.tokenizer.apply_chat_template(messages, tokenize=False)
inputs = llm.tokenizer(text=annotated_prompt, return_tensors="pt")

# %% [markdown]
# ### Batched generation

# %%
print(*llm.generate(**inputs, max_new_tokens=256))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 27 Jun 2025
#
# You are a helpful assistantuser
#
# Write 5 sentences of at least 5 words each, so that each sentence contains at least 1 word more than its orevious sentence.assistant
#
# Here are five sentences, each with more words than the previous one:
#
# 1. The sun was shining brightly in the clear blue sky.
# 2. The sun was shining brightly in the clear blue summer sky.
# 3. The sun was shining brightly in the clear blue summer sky every day.
# 4. The sun was shining brightly in the clear blue summer sky every single day.
# 5. The sun was shining brightly in the clear blue summer sky every single sunny day.

# %% [markdown]
# ### Streamed Generation

# %%
from transformers import TextStreamer
_ = llm.model.generate(**inputs, streamer=TextStreamer(llm.tokenizer), max_new_tokens=256)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <|begin_of_text|><|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 27 Jun 2025
#
# You are a helpful assistant<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Write 5 sentences of at least 5 words each, so that each sentence contains at least 1 word more than its orevious sentence.<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# Here are five sentences with at least five words each:
#
# 1. The old mansion had been standing for centuries quietly.
# 2. The old mansion had been standing for centuries quietly silently.
# 3. The old mansion had been standing for centuries silently quietly for centuries.
# 4. The old mansion had been standing for centuries silently quietly for centuries a long time.
# 5. The old mansion had been standing for centuries silently quietly for centuries a long time very long.<|eot_id|>

# %% [markdown]
# # `meta-llama/Llama-3.2-1B`

# %%
llm = util.ModelConfig.from_pretrained("meta-llama/Llama-3.2-1B")

# %%
from transformers import AutoTokenizer

# Call generate using a plain and an annotated prompt
plain_prompt = "Write 5 sentences of at least 5 words each, so that each sentence contains at least 1 word more than its orevious sentence."

messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": plain_prompt}
]

# this model is old, without a chat template. We exploit another tokenizer to convert the chat template to a string
chat_tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B-Instruct")

# tokenize=False will make the tokenizer return a string, otherwise a list with the token_ids is returned
annotated_prompt = chat_tokenizer.apply_chat_template(messages, tokenize=False)
inputs = llm.tokenizer(text=annotated_prompt, return_tensors="pt")

# %% [markdown]
# ## Batched generation

# %%
# print(*llm.generate(**inputs, max_new_tokens=256))
print(llm.tokenizer.batch_decode(llm.model.generate(**inputs, max_new_tokens=256)))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ['<|begin_of_text|><|begin_of_text|><|start_header_id|>system<|end_header_id|>\n\nCutting Knowledge Date: December 2023\nToday Date: 27 Jun 2025\n\nYou are a helpful assistant<|eot_id|><|start_header_id|>user<|end_header_id|>\n\nWrite 5 sentences of at least 5 words each, so that each sentence contains at least 1 word more than its orevious sentence.<|eot_id|>ें\n\nThe first sentence should be 1 word longer than the previous sentence. The second sentence should be 1 word longer than the previous sentence. The third sentence should be 1 word longer than the previous sentence. The fourth sentence should be 1 word longer than the previous sentence. The fifth sentence should be 1 word longer than the previous sentence.\n\nThe first sentence should be 1 word longer than the previous sentence. The second sentence should be 1 word longer than the previous sentence. The third sentence should be 1 word longer than the previous sentence. The fourth sentence should be 1 word longer than the previous sentence. The fifth sentence should be 1 word longer than the previous sentence.\n\nThe first sentence should be 1 word longer than the previous sentence. The second sentence should be 1 word longer than the previous sentence. The third sentence should be 1 word longer than the previous sentence. The fourth sentence should be 1 word longer than the previous sentence. The fifth sentence should be 1 word longer than the previous sentence.\n\nThe first sentence should be 1 word longer than the previous sentence. The second sentence should be 1 word longer than the previous sentence. The third sentence should be 1 word longer than the previous sentence. The fourth sentence']

# %% [markdown]
# ## Streamed Generation

# %%
from transformers import TextStreamer
_ = llm.model.generate(**inputs, streamer=TextStreamer(llm.tokenizer), max_new_tokens=256)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <|begin_of_text|><|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 27 Jun 2025
#
# You are a helpful assistant<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Write 5 sentences of at least 5 words each, so that each sentence contains at least 1 word more than its orevious sentence.<|eot_id|>ocê are not allowed to use punctuation or capitalization.ďte you can use the same words in each sentence, but you must change the order of the words in each sentence.ďte you must not use the same word twice in the same sentence.ďte you must not use the same word in more than one sentence.
#
# You may use the same words in each sentence, but you must change the order of the words in each sentence.ďte you must not use the same word twice in the same sentence.ďte you must not use the same word in more than one sentence.ďte you must not use the same word in more than one sentence.ďte you must not use the same word in more than one sentence.ďte you must not use the same word in more than one sentence.ďte you must not use the same word in more than one sentence.ďte you must not use the same word in more than one sentence.ďte you must not use the same word in more than one sentence.ďte you must not use the same word in more than one sentence.ďte you must not use the same word in more than one sentence.ďte you must not use the same word in more than one sentence.ďte you must not use the same word in more than one sentence.ďte you
